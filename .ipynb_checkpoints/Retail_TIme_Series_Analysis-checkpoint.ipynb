# %% [markdown]
# ***Time Series Analysis of Rossman store Dataset***
#
# In this section, all different methodology to analyze time series records will be discussed. We will be using statsmodels python module for data analysis efficiently.
#
# References:
#
# 1. Youtube: https://www.youtube.com/watch?v=DeORzP0go5I&list=PLvcbYUQ5t0UHOLnBzl46_Q6QKtFgfMGc3&index=2
#
# 2. Textbook: https://otexts.com/fpp3/determining-what-to-forecast.html

# %% [markdown]
# ***Statsmodels:***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ***Load the data***

# %%
data_f = pd.read_csv("/Users/adityatripathi/Desktop/Court_Documents/Projects/Time_Series_Rossman_Retail/rossmann_dataset.csv"
                    , index_col='Date'
                    , parse_dates=True,
                     sort_values
                    )
# Out:
# /var/folders/x2/klypyxc135nfqxlbmhpj3zq40000gn/T/ipykernel_56325/24539870.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_f = pd.read_csv("/Users/adityatripathi/Desktop/Court_Documents/Projects/Time_Series_Rossman_Retail/rossmann_dataset.csv"

# %%
data_f.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday
# Date
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-31              1

# %%
data_f.shape
# Out:
# (1017209, 8)

# %%
#Let's see what we can do here

# %% [markdown]
# ***Plot***

# %%
#Sorting the data which is our index here.
data_f.sort_index(inplace = True)

# %%
data_f.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-01-01   1115          2      0          0     0      0            a
# 2013-01-01    379          2      0          0     0      0            a
# 2013-01-01    378          2      0          0     0      0            a
# 2013-01-01    377          2      0          0     0      0            a
# 2013-01-01    376          2      0          0     0      0            a
#
#             SchoolHoliday
# Date
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1
# 2013-01-01              1

# %%
#filter our first store and look for what is it saying
data_f1 = data_f.loc[data_f['Store'] == 1]

# %%
data_f1.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-01-01      1          2      0          0     0      0            a
# 2013-01-02      1          3   5530        668     1      0            0
# 2013-01-03      1          4   4327        578     1      0            0
# 2013-01-04      1          5   4486        619     1      0            0
# 2013-01-05      1          6   4997        635     1      0            0
#
#             SchoolHoliday
# Date
# 2013-01-01              1
# 2013-01-02              1
# 2013-01-03              1
# 2013-01-04              1
# 2013-01-05              1

# %%
#Plotting our sales for store 1 to see the real meaning
#We observed sudden drops, spikes and also a middle flat layer 
#Sudden drops are happening, spikes happen at Jan of every year(2014, 2015) and in general the trend in middle graph is flat
ax = data_f1['Sales'].plot()

# %%
#Let's look what are these crashes at zero
#This proves that there was not a single day when the sales was 
data_f1.loc[(data_f1['Open'] == 1) & (data_f1['Sales'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Store, DayOfWeek, Sales, Customers, Open, Promo, StateHoliday, SchoolHoliday]
# Index: []

# %%
#So inorder to figure out the the zero crashes, we need to look into weekly totals.
Weekly_Sales = data_f1.resample('W').sum()

# %%
#Look how the zero crashes are gone.
#Just think we would have feeded the previous data to our algo it would have crashed instantly.
#Just by taking weekly sales the lowest the store ever drop is around 20,000. Ignoring those zero crashes in daily sales graph.
ay = Weekly_Sales['Sales'].plot()

# %% [markdown]
# ***Recognized daily sales data as noisy for baseline analysis. Selected weekly aggregation as the baseline timeline.***

# %%
#Now we are going to use famous Python Library called statsmodels to physically rip this sinle blue line apart
#Into three separate graphs so we can see the pure trend without holiday spikes getting in the way.
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Out:
# (31, 1)

# %%
# Out:
# [Text(0, 0.5, 'Total Monthly Sales')]

# %%
# Out:
# Requirement already satisfied: statsmodels in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: scipy>=1.3 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in /Users/adityatripathi/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)

# %%
# Out:
# 12
